# %%
import json
import pandas as pd
from pathlib import Path

data_path = Path("data/raw/spotify_export")

records = []

for file in data_path.glob("StreamingHistory*.json"):
    with open(file, "r", encoding="utf-8") as f:
        records.extend(json.load(f))

df = pd.DataFrame(records)
df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []
